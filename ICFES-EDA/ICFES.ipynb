# %% [markdown]
# LAURA ESPINOSA
#
#
# MELINA IMBACHI
#
#
# SANTIAGO GUTIERREZ

# %%
import pandas as pd
import numpy as np
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns

# %%
filePath = './SABERTYT20162.csv'

dfInvima = pd.read_csv(filePath, encoding='latin1', sep=';', decimal=',')

df = dfInvima[['ESTU_ESTADO', 'MOD_RAZONA_CUANTITAT_PUNT', 'MOD_RAZONA_CUANTITATIVO_PNAL', 'MOD_RAZONA_CUANTITATIVO_PGREF', 'MOD_LECTURA_CRITICA_PUNT', 'MOD_LECTURA_CRITICA_PNAL', 'MOD_LECTURA_CRITICA_PGREF', 'MOD_COMPETEN_CIUDADA_PUNT', 'MOD_COMPETEN_CIUDADA_PNAL', 'MOD_COMPETEN_CIUDADA_PGREF', 'MOD_INGLES_PUNT', 'MOD_INGLES_PNAL', 'MOD_INGLES_PGREF', 'MOD_COMUNI_ESCRITA_PUNT', 'MOD_COMUNI_ESCRITA_PNAL', 'MOD_COMUNI_ESCRITA_PGREF', 'ESTU_FECHANACIMIENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'ESTU_TIENE_ETNIA', 'ESTU_ETNIA'
               ,'ESTU_LIMITA_AUTISMO', 'ESTU_LIMITA_SORDO', 'ESTU_LIMITA_CONDICIONESPECIAL', 'ESTU_LIMITA_INVIDENTE', 'ESTU_LIMITA_MOTRIZ', 'FAMI_ESTRATO_VIVIENDA', 'INSE', 'NSE']]
# Out:
# C:\Users\santi\AppData\Local\Temp\ipykernel_24300\152617348.py:3: DtypeWarning: Columns (11,12,14,61) have mixed types. Specify dtype option on import or set low_memory=False.
#   dfInvima = pd.read_csv(filePath, encoding='latin1', sep=';', decimal=',')

# %%
df.head()
# Out:
#   ESTU_ESTADO  MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0    PUBLICAR                         80                            24
# 1    PUBLICAR                        122                            88
# 2    PUBLICAR                        115                            80
# 3    PUBLICAR                         82                            28
# 4    PUBLICAR                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# ...

# %%
df.isna().sum()
# Out:
# ESTU_ESTADO                          0
# MOD_RAZONA_CUANTITAT_PUNT            0
# MOD_RAZONA_CUANTITATIVO_PNAL         0
# MOD_RAZONA_CUANTITATIVO_PGREF        0
# MOD_LECTURA_CRITICA_PUNT             0
# MOD_LECTURA_CRITICA_PNAL             0
# MOD_LECTURA_CRITICA_PGREF            0
# MOD_COMPETEN_CIUDADA_PUNT            0
# MOD_COMPETEN_CIUDADA_PNAL            0
# MOD_COMPETEN_CIUDADA_PGREF           0
# MOD_INGLES_PUNT                      0
# MOD_INGLES_PNAL                      0
# MOD_INGLES_PGREF                     0
# MOD_COMUNI_ESCRITA_PUNT            787
# MOD_COMUNI_ESCRITA_PNAL            787
# MOD_COMUNI_ESCRITA_PGREF           787
# ESTU_FECHANACIMIENTO                 1
# ESTU_NACIONALIDAD                    0
# ESTU_GENERO                          2
# ESTU_TIENE_ETNIA                  4333
# ESTU_ETNIA                       49937
# ESTU_LIMITA_AUTISMO              53037
# ESTU_LIMITA_SORDO                53011
# ESTU_LIMITA_CONDICIONESPECIAL    53033
# ...

# %%
df.shape
# Out:
# (53040, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53040 entries, 0 to 53039
# Data columns (total 29 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ESTU_ESTADO                    53040 non-null  object
#  1   MOD_RAZONA_CUANTITAT_PUNT      53040 non-null  int64
#  2   MOD_RAZONA_CUANTITATIVO_PNAL   53040 non-null  int64
#  3   MOD_RAZONA_CUANTITATIVO_PGREF  53040 non-null  int64
#  4   MOD_LECTURA_CRITICA_PUNT       53040 non-null  int64
#  5   MOD_LECTURA_CRITICA_PNAL       53040 non-null  int64
#  6   MOD_LECTURA_CRITICA_PGREF      53040 non-null  int64
#  7   MOD_COMPETEN_CIUDADA_PUNT      53040 non-null  int64
#  8   MOD_COMPETEN_CIUDADA_PNAL      53040 non-null  int64
#  9   MOD_COMPETEN_CIUDADA_PGREF     53040 non-null  int64
#  10  MOD_INGLES_PUNT                53040 non-null  int64
#  11  MOD_INGLES_PNAL                53040 non-null  int64
# ...

# %%
df = df[(df['ESTU_ESTADO'] == 'PUBLICAR') & (df['ESTU_NACIONALIDAD'] == '1 COLOMBIA')]
df.head()
# Out:
#   ESTU_ESTADO  MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0    PUBLICAR                         80                            24
# 1    PUBLICAR                        122                            88
# 2    PUBLICAR                        115                            80
# 3    PUBLICAR                         82                            28
# 4    PUBLICAR                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# ...

# %%
df = df.dropna(subset=['ESTU_FECHANACIMIENTO'])

# %%
df['Fecha_de_nacimiento'] = pd.to_datetime(df['ESTU_FECHANACIMIENTO'], format='%d/%m/%Y')
df['Fecha_de_nacimiento'].head()
# Out:
# 0   1990-08-15
# 1   1990-09-26
# 2   1994-10-28
# 3   1979-09-24
# 4   1988-07-06
# Name: Fecha_de_nacimiento, dtype: datetime64[ns]

# %%
dateNow = '09/10/2016'
dateNow = datetime.strptime(dateNow, '%d/%m/%Y')
df['Edad'] = (dateNow - df['Fecha_de_nacimiento']).dt.days // 365

# %%
df['Edad'].head()
# Out:
# 0    26
# 1    26
# 2    21
# 3    37
# 4    28
# Name: Edad, dtype: int64

# %%
df = df.drop(['ESTU_FECHANACIMIENTO', 'ESTU_NACIONALIDAD', 'ESTU_ESTADO', 'Fecha_de_nacimiento'], axis=1)
df.head()
# Out:
#    MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0                         80                            24
# 1                        122                            88
# 2                        115                            80
# 3                         82                            28
# 4                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# 2                        83                         84
# ...

# %%
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT            0
# MOD_RAZONA_CUANTITATIVO_PNAL         0
# MOD_RAZONA_CUANTITATIVO_PGREF        0
# MOD_LECTURA_CRITICA_PUNT             0
# MOD_LECTURA_CRITICA_PNAL             0
# MOD_LECTURA_CRITICA_PGREF            0
# MOD_COMPETEN_CIUDADA_PUNT            0
# MOD_COMPETEN_CIUDADA_PNAL            0
# MOD_COMPETEN_CIUDADA_PGREF           0
# MOD_INGLES_PUNT                      0
# MOD_INGLES_PNAL                      0
# MOD_INGLES_PGREF                     0
# MOD_COMUNI_ESCRITA_PUNT            770
# MOD_COMUNI_ESCRITA_PNAL            770
# MOD_COMUNI_ESCRITA_PGREF           770
# ESTU_GENERO                          1
# ESTU_TIENE_ETNIA                  4291
# ESTU_ETNIA                       49578
# ESTU_LIMITA_AUTISMO              52661
# ESTU_LIMITA_SORDO                52635
# ESTU_LIMITA_CONDICIONESPECIAL    52657
# ESTU_LIMITA_INVIDENTE            52660
# ESTU_LIMITA_MOTRIZ               52618
# FAMI_ESTRATO_VIVIENDA                2
# ...

# %%
df.shape
# Out:
# (52664, 27)

# %% [markdown]
# Podemos ver que las variables de las discapacidades son casi nulas en su totalidad. Ya que las variables de discapacidad especifican las discapacidades, vamos a tomar los valores nulos como que no posee discapacidades.

# %%
columnas_discapacidades = ['ESTU_LIMITA_AUTISMO', 'ESTU_LIMITA_SORDO', 'ESTU_LIMITA_CONDICIONESPECIAL', 'ESTU_LIMITA_INVIDENTE', 'ESTU_LIMITA_MOTRIZ']

# Filtrar el DataFrame para mostrar solo las filas donde al menos una de las columnas de discapacidad no es nula
df_no_nulos_discapacidades = df[df[columnas_discapacidades].notna().any(axis=1)]

# Mostrar las primeras filas del DataFrame resultante
print(df_no_nulos_discapacidades.head())
# Out:
#       MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 650                          69                            11
# 1418                         76                            19
# 1707                         90                            39
# 1926                         67                            10
# 3227                         70                            13
#
#       MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 650                              10                        54
# 1418                             14                        75
# 1707                             40                       104
# 1926                              9                        82
# 3227                              8                        44
#
#       MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 650                          4                          4
# 1418                        19                         18
# ...

# %%
df['POSEE_INCAPACIDAD'] = df[columnas_discapacidades].notna().any(axis=1).astype(int)
df = df.drop(columnas_discapacidades, axis=1)
df.head()
# Out:
#    MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0                         80                            24
# 1                        122                            88
# 2                        115                            80
# 3                         82                            28
# 4                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# 2                        83                         84
# ...

# %%
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT            0
# MOD_RAZONA_CUANTITATIVO_PNAL         0
# MOD_RAZONA_CUANTITATIVO_PGREF        0
# MOD_LECTURA_CRITICA_PUNT             0
# MOD_LECTURA_CRITICA_PNAL             0
# MOD_LECTURA_CRITICA_PGREF            0
# MOD_COMPETEN_CIUDADA_PUNT            0
# MOD_COMPETEN_CIUDADA_PNAL            0
# MOD_COMPETEN_CIUDADA_PGREF           0
# MOD_INGLES_PUNT                      0
# MOD_INGLES_PNAL                      0
# MOD_INGLES_PGREF                     0
# MOD_COMUNI_ESCRITA_PUNT            770
# MOD_COMUNI_ESCRITA_PNAL            770
# MOD_COMUNI_ESCRITA_PGREF           770
# ESTU_GENERO                          1
# ESTU_TIENE_ETNIA                  4291
# ESTU_ETNIA                       49578
# FAMI_ESTRATO_VIVIENDA                2
# INSE                               753
# NSE                                753
# Edad                                 0
# POSEE_INCAPACIDAD                    0
# dtype: int64

# %%
df['ESTU_TIENE_ETNIA'].value_counts()
# Out:
# ESTU_TIENE_ETNIA
# NO    45097
# SI     3276
# Name: count, dtype: int64

# %%
df['ESTU_ETNIA'].value_counts()
# Out:
# ESTU_ETNIA
# 100 Ninguno                         1631
# 1 Comunidad afrodescendiente         681
# 19 Otro grupo étnico minoritario     445
# 4 Paez                                72
# 18 Zenú                               57
# 9 Pasto                               42
# 2 Raizal                              40
# 6 Embera                              32
# 7 Pijao                               21
# 8 Wayúu                               19
# 11 Inga                               16
# 17 Guambiano                          10
# 15 Palenquero                          7
# 10 Cancuamo                            3
# 3 Comunidad Rom (gitana)               3
# 16 Arhuaco                             3
# 12 Tucano                              2
# 13 Huitoto                             2
# Name: count, dtype: int64

# %%
# Crear la columna 'POSEE_ETNIA' basada en 'ESTU_TIENE_ETNIA'
df['POSEE_ETNIA'] = df['ESTU_TIENE_ETNIA'].apply(lambda x: 1 if x == 'SI' else 0)

# Identificar inconsistencias
inconsistencias = df[(df['POSEE_ETNIA'] == 1) & (df['ESTU_ETNIA'] == '100 Ninguno')]

# Mostrar las filas con inconsistencias
inconsistencias.head()
# Out:
#      MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 73                         101                            58
# 82                          73                            15
# 104                        120                            86
# 134                         88                            36
# 247                        116                            82
#
#      MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 73                              46                       110
# 82                              14                        61
# 104                             73                       118
# 134                             34                       107
# 247                             72                       123
#
#      MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 73                         73                         69
# 82                          8                          6
# ...

# %%
# Identificar y corregir inconsistencias: si 'ESTU_ETNIA' es "NINGUNA", ajustar 'POSEE_ETNIA' a 0
df.loc[df['ESTU_ETNIA'] == '100 Ninguno', 'POSEE_ETNIA'] = 0

# Mostrar las filas con inconsistencias
inconsistencias = df[(df['POSEE_ETNIA'] == 1) & (df['ESTU_ETNIA'] == '100 Ninguno')]

# Mostrar las primeras filas con inconsistencias corregidas
print(inconsistencias[['ESTU_TIENE_ETNIA', 'ESTU_ETNIA', 'POSEE_ETNIA']].head())
# Out:
# Empty DataFrame
# Columns: [ESTU_TIENE_ETNIA, ESTU_ETNIA, POSEE_ETNIA]
# Index: []

# %%
df = df.drop(['ESTU_TIENE_ETNIA', 'ESTU_ETNIA'], axis=1)
df.head()
# Out:
#    MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0                         80                            24
# 1                        122                            88
# 2                        115                            80
# 3                         82                            28
# 4                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# 2                        83                         84
# ...

# %%
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT          0
# MOD_RAZONA_CUANTITATIVO_PNAL       0
# MOD_RAZONA_CUANTITATIVO_PGREF      0
# MOD_LECTURA_CRITICA_PUNT           0
# MOD_LECTURA_CRITICA_PNAL           0
# MOD_LECTURA_CRITICA_PGREF          0
# MOD_COMPETEN_CIUDADA_PUNT          0
# MOD_COMPETEN_CIUDADA_PNAL          0
# MOD_COMPETEN_CIUDADA_PGREF         0
# MOD_INGLES_PUNT                    0
# MOD_INGLES_PNAL                    0
# MOD_INGLES_PGREF                   0
# MOD_COMUNI_ESCRITA_PUNT          770
# MOD_COMUNI_ESCRITA_PNAL          770
# MOD_COMUNI_ESCRITA_PGREF         770
# ESTU_GENERO                        1
# FAMI_ESTRATO_VIVIENDA              2
# INSE                             753
# NSE                              753
# Edad                               0
# POSEE_INCAPACIDAD                  0
# POSEE_ETNIA                        0
# dtype: int64

# %% [markdown]
# Veamos a ver como se comportan las notas nulas

# %%
columnas_notas = 'MOD_COMUNI_ESCRITA_PUNT'

sns.histplot(df[columnas_notas], kde=True)

# Agregar líneas para la media y la mediana
plt.axvline(df[columnas_notas].mean(), color='red', label='Media')
plt.axvline(df[columnas_notas].median(), color='green', label='Mediana')

plt.legend()
plt.show()

# %% [markdown]
# Como no tiene valor atipicos represtativos podemos cambiar los valores nulos por la media

# %%
columnas_notas = ['MOD_COMUNI_ESCRITA_PUNT', 'MOD_COMUNI_ESCRITA_PNAL', 'MOD_COMUNI_ESCRITA_PGREF']
df[columnas_notas] = df[columnas_notas].apply(lambda x: x.fillna(x.median()))
# df[columnas_notas].fillna(df[columnas_notas].mean(), inplace=True)
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT          0
# MOD_RAZONA_CUANTITATIVO_PNAL       0
# MOD_RAZONA_CUANTITATIVO_PGREF      0
# MOD_LECTURA_CRITICA_PUNT           0
# MOD_LECTURA_CRITICA_PNAL           0
# MOD_LECTURA_CRITICA_PGREF          0
# MOD_COMPETEN_CIUDADA_PUNT          0
# MOD_COMPETEN_CIUDADA_PNAL          0
# MOD_COMPETEN_CIUDADA_PGREF         0
# MOD_INGLES_PUNT                    0
# MOD_INGLES_PNAL                    0
# MOD_INGLES_PGREF                   0
# MOD_COMUNI_ESCRITA_PUNT            0
# MOD_COMUNI_ESCRITA_PNAL            0
# MOD_COMUNI_ESCRITA_PGREF           0
# ESTU_GENERO                        1
# FAMI_ESTRATO_VIVIENDA              2
# INSE                             753
# NSE                              753
# Edad                               0
# POSEE_INCAPACIDAD                  0
# POSEE_ETNIA                        0
# dtype: int64

# %% [markdown]
# Hacmos los mismo para INSE y NES

# %%
df[['NSE', 'INSE']].head()
# Out:
#     NSE       INSE
# 0  NSE3  57.142411
# 1  NSE4  65.766372
# 2  NSE2  47.681996
# 3  NSE3  55.563980
# 4  NSE1  27.013301

# %%
# Filtra los valores nulos
valores_limpios = [x for x in df['INSE'] if not pd.isnull(x)]

# Crea un histograma de los valores limpios
sns.histplot(valores_limpios, kde=True)

# Calcula la media y la mediana de los valores limpios
media = np.mean(valores_limpios)
mediana = np.median(valores_limpios)

# Agrega líneas para la media y la mediana en el gráfico
plt.axvline(media, color='red', label='Media')
plt.axvline(mediana, color='green', label='Mediana')

# Muestra la leyenda
plt.legend()

# Muestra el gráfico
plt.show()

# %%
df['INSE'].fillna(mediana, inplace=True)
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT          0
# MOD_RAZONA_CUANTITATIVO_PNAL       0
# MOD_RAZONA_CUANTITATIVO_PGREF      0
# MOD_LECTURA_CRITICA_PUNT           0
# MOD_LECTURA_CRITICA_PNAL           0
# MOD_LECTURA_CRITICA_PGREF          0
# MOD_COMPETEN_CIUDADA_PUNT          0
# MOD_COMPETEN_CIUDADA_PNAL          0
# MOD_COMPETEN_CIUDADA_PGREF         0
# MOD_INGLES_PUNT                    0
# MOD_INGLES_PNAL                    0
# MOD_INGLES_PGREF                   0
# MOD_COMUNI_ESCRITA_PUNT            0
# MOD_COMUNI_ESCRITA_PNAL            0
# MOD_COMUNI_ESCRITA_PGREF           0
# ESTU_GENERO                        1
# FAMI_ESTRATO_VIVIENDA              2
# INSE                               0
# NSE                              753
# Edad                               0
# POSEE_INCAPACIDAD                  0
# POSEE_ETNIA                        0
# dtype: int64

# %%
df['NSE'].value_counts()
# Out:
# NSE
# NSE2    20132
# NSE1    13837
# NSE4    10696
# NSE3     7246
# Name: count, dtype: int64

# %%
bins = np.linspace(min(df["INSE"]), max(df["INSE"]), 5)
bins
# Out:
# array([19.0333872 , 35.31097747, 51.58856773, 67.866158  , 84.14374826])

# %%
group_names = df['NSE'].value_counts().index.values
group_names.sort()
group_names
# Out:
# array(['NSE1', 'NSE2', 'NSE3', 'NSE4'], dtype=object)

# %%
mascara_nulos = df['NSE'].isnull()
df.loc[mascara_nulos, 'NSE'] = pd.cut(df.loc[mascara_nulos, 'INSE'], bins=bins, labels=False, include_lowest=True)
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT        0
# MOD_RAZONA_CUANTITATIVO_PNAL     0
# MOD_RAZONA_CUANTITATIVO_PGREF    0
# MOD_LECTURA_CRITICA_PUNT         0
# MOD_LECTURA_CRITICA_PNAL         0
# MOD_LECTURA_CRITICA_PGREF        0
# MOD_COMPETEN_CIUDADA_PUNT        0
# MOD_COMPETEN_CIUDADA_PNAL        0
# MOD_COMPETEN_CIUDADA_PGREF       0
# MOD_INGLES_PUNT                  0
# MOD_INGLES_PNAL                  0
# MOD_INGLES_PGREF                 0
# MOD_COMUNI_ESCRITA_PUNT          0
# MOD_COMUNI_ESCRITA_PNAL          0
# MOD_COMUNI_ESCRITA_PGREF         0
# ESTU_GENERO                      1
# FAMI_ESTRATO_VIVIENDA            2
# INSE                             0
# NSE                              0
# Edad                             0
# POSEE_INCAPACIDAD                0
# POSEE_ETNIA                      0
# dtype: int64

# %%
df.dropna(inplace=True)
df.isna().sum()
# Out:
# MOD_RAZONA_CUANTITAT_PUNT        0
# MOD_RAZONA_CUANTITATIVO_PNAL     0
# MOD_RAZONA_CUANTITATIVO_PGREF    0
# MOD_LECTURA_CRITICA_PUNT         0
# MOD_LECTURA_CRITICA_PNAL         0
# MOD_LECTURA_CRITICA_PGREF        0
# MOD_COMPETEN_CIUDADA_PUNT        0
# MOD_COMPETEN_CIUDADA_PNAL        0
# MOD_COMPETEN_CIUDADA_PGREF       0
# MOD_INGLES_PUNT                  0
# MOD_INGLES_PNAL                  0
# MOD_INGLES_PGREF                 0
# MOD_COMUNI_ESCRITA_PUNT          0
# MOD_COMUNI_ESCRITA_PNAL          0
# MOD_COMUNI_ESCRITA_PGREF         0
# ESTU_GENERO                      0
# FAMI_ESTRATO_VIVIENDA            0
# INSE                             0
# NSE                              0
# Edad                             0
# POSEE_INCAPACIDAD                0
# POSEE_ETNIA                      0
# dtype: int64

# %%
df.head()
# Out:
#    MOD_RAZONA_CUANTITAT_PUNT  MOD_RAZONA_CUANTITATIVO_PNAL  \
# 0                         80                            24
# 1                        122                            88
# 2                        115                            80
# 3                         82                            28
# 4                         95                            49
#
#    MOD_RAZONA_CUANTITATIVO_PGREF  MOD_LECTURA_CRITICA_PUNT  \
# 0                             22                       114
# 1                             89                       112
# 2                             84                       117
# 3                             26                       101
# 4                             57                       106
#
#    MOD_LECTURA_CRITICA_PNAL  MOD_LECTURA_CRITICA_PGREF  \
# 0                        80                         70
# 1                        77                         75
# 2                        83                         84
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52661 entries, 0 to 53039
# Data columns (total 22 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   MOD_RAZONA_CUANTITAT_PUNT      52661 non-null  int64
#  1   MOD_RAZONA_CUANTITATIVO_PNAL   52661 non-null  int64
#  2   MOD_RAZONA_CUANTITATIVO_PGREF  52661 non-null  int64
#  3   MOD_LECTURA_CRITICA_PUNT       52661 non-null  int64
#  4   MOD_LECTURA_CRITICA_PNAL       52661 non-null  int64
#  5   MOD_LECTURA_CRITICA_PGREF      52661 non-null  int64
#  6   MOD_COMPETEN_CIUDADA_PUNT      52661 non-null  int64
#  7   MOD_COMPETEN_CIUDADA_PNAL      52661 non-null  int64
#  8   MOD_COMPETEN_CIUDADA_PGREF     52661 non-null  int64
#  9   MOD_INGLES_PUNT                52661 non-null  int64
#  10  MOD_INGLES_PNAL                52661 non-null  int64
#  11  MOD_INGLES_PGREF               52661 non-null  int64
# ...

# %%
temp = df.drop( axis = 1, columns= ['ESTU_GENERO', 'FAMI_ESTRATO_VIVIENDA', 'NSE'])
corrmat = temp.corr()
fig,ax = plt.subplots(figsize=(20,15))
hm = sns.heatmap(corrmat,
                 cbar=True,
                 annot=True,
                 square=True,
                 fmt='.2f',
                 annot_kws={'size': 10},
                 yticklabels=temp.columns,
                 xticklabels=temp.columns,
                 cmap="Spectral_r", ax=ax)
plt.show()
